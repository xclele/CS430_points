# %% [markdown]
# ## Import the libs

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Now Start!

# %%
x = np.linspace(1,40,20)
y = x ** 2 + 10

plt.plot(x,y)

p = np.linspace(1,40,20)
q = p + 10

plt.plot(p,q)

# %%
p = np.linspace(1,40,20)
q = p + 10

plt.plot(p,q)
plt.show()
